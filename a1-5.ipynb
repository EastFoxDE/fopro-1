# %%
#### NOCH NICHTS GEÄNDERT
#### STAND VON a4!
import matplotlib.pyplot as plt
import numpy as np
from diffType import *
import math
import random

def sim(v0,angle,target):
    u = 2.0 * math.pi * angle / 360.0 
    d_y0 = v0 * u.sin() 
    d_x0 = v0 * u.cos() 
    
    # const
    g = 9.81
    t = 0.0 

    # Manthon Optimierung
    t = 2.0 / g * d_y0
    x = d_x0 * t
    return (target-x)**2

def minimize(v0,ang0,step):
    velo = diffType(v0)
    angle = diffType(ang0)

    eps = 1E-7
    step = 0.001
    count = 0
    
    while(1): 
        count += 1
    
        # Diff after velocity
        velo.dvalue = 1.0
        angle.dvalue = 0.0
        fx = sim(velo, angle,target)
        velo_dval = fx.dvalue
    
        # Diff after angle
        velo.dvalue = 0.0
        angle.dvalue = 1.0
        fx = sim(velo, angle,target)
        angle_dval = fx.dvalue
    
        #Debug
        #if(count % 100):
        #    pass #print(fx.value)
    
        if(fx.value < eps):
            break
    
        # Gradient descent
        velo = velo - step * velo_dval
        angle = angle - step * angle_dval
        
    #\x1b[31m\"red\"\x1b[0m"
    
    
    print(f"To land after exact \x1b[32m{target:.2f}\x1b[0m meter the velocity must be \x1b[31m{velo.value:.3f}\x1b[0m m/s with an angle of \x1b[31m{angle.value:.2f}\x1b[0m degrees.")
    print(f"The start values were: velocity = {v0:.2f}m/s | angle = {ang0:.2f} deg")
    print(f"Gradient count was: {count}")
    print("")
    
### init

random.seed()
for i in range(0,10):
    velo = random.uniform(5.0,50.0)
    angle = random.uniform(0.0,90.0)
    target = random.uniform(20.0,100.0) #20.0
    
    minimize(velo,angle,target)
# Out:
# To land after exact 28.62 meter the velocity must be 19.587 m/s with an angle of 23.52 degrees.
# The start values were: velocity = 5.13m/s | angle = 20.28 deg
# Gradient count was: 779
#
# To land after exact 25.47 meter the velocity must be 15.865 m/s with an angle of 41.52 degrees.
# The start values were: velocity = 14.81m/s | angle = 41.48 deg
# Gradient count was: 451
#
# To land after exact 53.84 meter the velocity must be 37.422 m/s with an angle of 78.92 degrees.
# The start values were: velocity = 35.97m/s | angle = 81.54 deg
# Gradient count was: 182
#
# To land after exact 92.95 meter the velocity must be 33.470 m/s with an angle of 62.76 degrees.
# The start values were: velocity = 22.01m/s | angle = 67.41 deg
# Gradient count was: 179
#
# To land after exact 39.20 meter the velocity must be 20.060 m/s with an angle of 36.43 degrees.
# The start values were: velocity = 16.79m/s | angle = 36.10 deg
# Gradient count was: 349
#
# To land after exact 64.42 meter the velocity must be 37.095 m/s with an angle of 13.67 degrees.
# The start values were: velocity = 39.32m/s | angle = 16.24 deg
# Gradient count was: 170
#
# To land after exact 28.25 meter the velocity must be 20.374 m/s with an angle of 69.06 degrees.
# The start values were: velocity = 10.26m/s | angle = 72.45 deg
# Gradient count was: 731
#
# To land after exact 58.11 meter the velocity must be 30.576 m/s with an angle of 71.21 degrees.
# The start values were: velocity = 19.00m/s | angle = 80.39 deg
# Gradient count was: 324
#
# To land after exact 32.08 meter the velocity must be 20.019 m/s with an angle of 25.87 degrees.
# The start values were: velocity = 15.62m/s | angle = 24.75 deg
# Gradient count was: 504
#
# To land after exact 45.30 meter the velocity must be 41.889 m/s with an angle of 82.66 degrees.
# The start values were: velocity = 46.90m/s | angle = 73.94 deg
# Gradient count was: 140
